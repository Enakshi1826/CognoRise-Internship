# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("./Test.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df.shape
# Out:
# (5681, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
df.reset_index()
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDW58       20.750          Low Fat         0.007565
# 1         1           FDW14        8.300              reg         0.038428
# 2         2           NCN55       14.600          Low Fat         0.099575
# 3         3           FDQ58        7.315          Low Fat         0.015388
# 4         4           FDY38          NaN          Regular         0.118599
# ...     ...             ...          ...              ...              ...
# 5676   5676           FDB58       10.500          Regular         0.013496
# 5677   5677           FDD47        7.600          Regular         0.142991
# 5678   5678           NCO17       10.000          Low Fat         0.073529
# 5679   5679           FDJ26       15.300          Regular         0.000000
# 5680   5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %%
df["Item_Weight"].unique()
# Out:
# array([20.75 ,  8.3  , 14.6  ,  7.315,    nan,  9.8  , 19.35 ,  6.305,
#         5.985, 16.6  ,  6.59 ,  4.785, 16.75 ,  6.135, 19.85 , 17.85 ,
#        13.6  ,  7.1  , 19.2  , 13.65 ,  6.785, 13.   ,  5.825, 13.8  ,
#        12.8  ,  9.5  , 12.5  ,  5.78 , 10.395, 18.35 , 21.1  , 19.75 ,
#         8.43 , 15.35 ,  6.71 , 10.195, 11.65 , 12.85 , 12.15 , 18.25 ,
#         5.98 , 12.65 , 13.1  , 20.7  ,  7.855, 13.35 , 17.25 ,  8.315,
#        21.35 ,  5.88 ,  7.435, 14.65 , 14.   , 18.2  , 17.6  ,  7.71 ,
#         7.81 , 16.35 , 16.1  ,  5.34 ,  5.51 ,  6.61 ,  6.38 ,  8.71 ,
#        17.75 ,  6.44 , 12.6  ,  7.935, 18.5  ,  6.035, 11.8  ,  6.26 ,
#        16.5  , 15.7  ,  6.635,  8.155,  6.175,  8.18 ,  8.355,  6.905,
#        20.35 , 19.25 ,  5.48 ,  5.425, 12.1  , 11.   ,  5.765,  5.44 ,
#         6.13 ,  8.195, 14.15 , 14.3  ,  5.635,  5.73 ,  7.155, 15.2  ,
#        15.25 ,  8.76 ,  9.13 , 19.6  , 10.   , 11.3  ,  6.57 , 13.15 ,
# ...

# %%
df["Item_Weight"].value_counts().reset_index()
# Out:
#      Item_Weight  count
# 0         10.500     57
# 1         17.600     53
# 2         15.600     48
# 3         20.250     47
# 4         19.350     46
# ..           ...    ...
# 405        6.980      1
# 406        6.320      1
# 407        5.465      1
# 408        5.945      1
# 409        7.670      1
#
# [410 rows x 2 columns]

# %%
df["Item_Weight"].reset_index()
# Out:
#       index  Item_Weight
# 0         0       20.750
# 1         1        8.300
# 2         2       14.600
# 3         3        7.315
# 4         4          NaN
# ...     ...          ...
# 5676   5676       10.500
# 5677   5677        7.600
# 5678   5678       10.000
# 5679   5679       15.300
# 5680   5680        9.500
#
# [5681 rows x 2 columns]

# %%
df["Item_Weight"].reset_index().plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
df["Item_Weight"].describe()
# Out:
# count    4705.000000
# mean       12.695633
# std         4.664849
# min         4.555000
# 25%         8.645000
# 50%        12.500000
# 75%        16.700000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.value_counts().plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Item_Weight'>

# %%
df["Item_Type"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0              Snack Foods
# 1                    Dairy
# 2                   Others
# 3              Snack Foods
# 4                    Dairy
#                ...
# 5676           Snack Foods
# 5677         Starchy Foods
# 5678    Health and Hygiene
# 5679                Canned
# 5680                Canned
# Name: Item_Type, Length: 5681, dtype: object>

# %%
df["Item_Type"].reset_index()
# Out:
#       index           Item_Type
# 0         0         Snack Foods
# 1         1               Dairy
# 2         2              Others
# 3         3         Snack Foods
# 4         4               Dairy
# ...     ...                 ...
# 5676   5676         Snack Foods
# 5677   5677       Starchy Foods
# 5678   5678  Health and Hygiene
# 5679   5679              Canned
# 5680   5680              Canned
#
# [5681 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x="Item_Weight",bins=15,kde=True,color="green")
plt.title("Distribution of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")
plt.show()

# %%
df.Item_Visibility.value_counts()
# Out:
# Item_Visibility
# 0.000000    353
# 0.060879      2
# 0.097213      2
# 0.058461      2
# 0.058132      2
#            ...
# 0.082382      1
# 0.026175      1
# 0.155144      1
# 0.069557      1
# 0.104720      1
# Name: count, Length: 5277, dtype: int64

# %%
df["Item_Visibility"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x="Item_MRP",bins=15,kde=True,color="blue")
plt.title("Distribution of Item_MRP")
plt.xlabel("Item_MRP")
plt.ylabel("Frequency")
plt.show()

# %%
df.isnull().sum().reset_index().rename(columns={0:'count'})
# Out:
#                         index  count
# 0             Item_Identifier      0
# 1                 Item_Weight    976
# 2            Item_Fat_Content      0
# 3             Item_Visibility      0
# 4                   Item_Type      0
# 5                    Item_MRP      0
# 6           Outlet_Identifier      0
# 7   Outlet_Establishment_Year      0
# 8                 Outlet_Size   1606
# 9        Outlet_Location_Type      0
# 10                Outlet_Type      0

# %%
df["Outlet_Identifier"].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       OUT049
# 1       OUT017
# 2       OUT010
# 3       OUT017
# 4       OUT027
#          ...
# 5676    OUT046
# 5677    OUT018
# 5678    OUT045
# 5679    OUT017
# 5680    OUT045
# Name: Outlet_Identifier, Length: 5681, dtype: object>

# %%
df["Outlet_Identifier"].describe()
# Out:
# count       5681
# unique        10
# top       OUT027
# freq         624
# Name: Outlet_Identifier, dtype: object

# %%
sns.countplot(x=df["Outlet_Identifier"])
# Out:
# <Axes: xlabel='Outlet_Identifier', ylabel='count'>

# %%
df["Outlet_Establishment_Year"].reset_index()
# Out:
#       index  Outlet_Establishment_Year
# 0         0                       1999
# 1         1                       2007
# 2         2                       1998
# 3         3                       2007
# 4         4                       1985
# ...     ...                        ...
# 5676   5676                       1997
# 5677   5677                       2009
# 5678   5678                       2002
# 5679   5679                       2007
# 5680   5680                       2002
#
# [5681 rows x 2 columns]

# %%
df["Outlet_Establishment_Year"].value_counts().plot(kind='bar',figsize=(10,6))
# Out:
# <Axes: xlabel='Outlet_Establishment_Year'>

# %%
continuous_columns=['Item_Weight','Item_Visibility','Item_MRP']
for column in continuous_columns:
 plt.figure(figsize=(10,5))
 
 sns.histplot(data=df,x=column,bins=15,kde=True,color='brown')
 plt.title(f"Histogram of {column}")
 plt.xlabel(column)
 plt.ylabel('Frequency') 
 plt.grid(True)
 plt.show()
 
 plt.figure(figsize=(8,4))
 sns.boxplot(data=df,y=column)
 plt.title(f"Box Plot of {column}")
 plt.xlabel(column) 
 plt.grid(True)
 plt.show()
