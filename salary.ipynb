# %%
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("./ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.iloc[[455-555]]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 507         507       2022               MI              FT
#
#               job_title  salary salary_currency  salary_in_usd  \
# 507  Research Scientist   59000             EUR          64849
#
#     employee_residence  remote_ratio company_location company_size
# 507                 AT             0               AT            L

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.isnull().sum().reset_index().rename(columns={0:'count'})
# Out:
#                  index  count
# 0           Unnamed: 0      0
# 1            work_year      0
# 2     experience_level      0
# 3      employment_type      0
# 4            job_title      0
# 5               salary      0
# 6      salary_currency      0
# 7        salary_in_usd      0
# 8   employee_residence      0
# 9         remote_ratio      0
# 10    company_location      0
# 11        company_size      0

# %%
df["salary"].value_counts().reset_index()
# Out:
#       salary  count
# 0     100000     18
# 1      80000     18
# 2     120000     15
# 3      60000     15
# 4     150000     14
# ..       ...    ...
# 267   256000      1
# 268    39600      1
# 269  1335000      1
# 270    52500      1
# 271   129000      1
#
# [272 rows x 2 columns]

# %%
plt.scatter(df["experience_level"],df["salary"],color="black")
plt.xlabel("salary")
plt.ylabel("experience_level")
# Out:
# Text(0, 0.5, 'experience_level')

# %%
sns.countplot(x=df["remote_ratio"])
# Out:
# <Axes: xlabel='remote_ratio', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="salary",bins=15,kde=True,color='blue')
plt.title("Distribution of Salary")
plt.xlabel("salary")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df,x="experience_level",bins=15,kde=True,color='blue')
plt.title("Distribution of experience_level")
plt.xlabel("experience_level")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
df["salary"].reset_index()
# Out:
#      index  salary
# 0        0   70000
# 1        1  260000
# 2        2   85000
# 3        3   20000
# 4        4  150000
# ..     ...     ...
# 602    602  154000
# 603    603  126000
# 604    604  129000
# 605    605  150000
# 606    606  200000
#
# [607 rows x 2 columns]

# %%
df_g=df.groupby('job_title')['salary'].apply(lambda x:x.mode().iloc[0]).reset_index()
df_g.columns=['job_title','salary']
df_g
# Out:
#                                    job_title   salary
# 0              3D Computer Vision Researcher   400000
# 1                               AI Scientist    12000
# 2                         Analytics Engineer   135000
# 3                     Applied Data Scientist    68000
# 4         Applied Machine Learning Scientist    29000
# 5                            BI Data Analyst     9272
# 6                         Big Data Architect   125000
# 7                          Big Data Engineer    18000
# 8                      Business Data Analyst    50000
# 9                        Cloud Data Engineer   120000
# 10                  Computer Vision Engineer    10000
# 11         Computer Vision Software Engineer    70000
# 12                              Data Analyst    90320
# 13                   Data Analytics Engineer    20000
# 14                       Data Analytics Lead   405000
# 15                    Data Analytics Manager   120000
# ...

# %%
df["salary"].unique()
# Out:
# array([   70000,   260000,    85000,    20000,   150000,    72000,
#          190000, 11000000,   135000,   125000,    45000,  3000000,
#           35000,    87000,     8000,  4450000,   100000,   423000,
#           56000,   299000,   450000,    42000,    98000,   115000,
#          325000,   720000,   157000,    51999,    60000,    41000,
#           65000,   103000,   250000,    10000,   138000,    45760,
#           44000,   106000,    88000,    14000,   188000,   105000,
#           61500,    91000,   300000,    48000,   130000,    34000,
#          118000,   120000,   138350,   110000,   130800,    19000,
#          412000,    40000,    55000,    43200,   190200,    80000,
#           37000,   235000,   400000,   270000,    67000,   140000,
#           68000,    50000,   170000,    75000,  1450000,   276000,
#         2200000,    12000,    81000,    62000,    73000,    37456,
#         2250000,    82500,    38400,   225000,    90000,   200000,
# ...

# %%
df.reset_index()
# Out:
#      index  Unnamed: 0  work_year experience_level employment_type  \
# 0        0           0       2020               MI              FT
# 1        1           1       2020               SE              FT
# 2        2           2       2020               SE              FT
# 3        3           3       2020               MI              FT
# 4        4           4       2020               SE              FT
# ..     ...         ...        ...              ...             ...
# 602    602         602       2022               SE              FT
# 603    603         603       2022               SE              FT
# 604    604         604       2022               SE              FT
# 605    605         605       2022               SE              FT
# 606    606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
df["salary"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="remote_ratio",bins=15,kde=True,color='skyblue')
plt.title("Distribution of remote_ratio")
plt.xlabel("remote_ratio")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
df["salary"].describe()
# Out:
# count    6.070000e+02
# mean     3.240001e+05
# std      1.544357e+06
# min      4.000000e+03
# 25%      7.000000e+04
# 50%      1.150000e+05
# 75%      1.650000e+05
# max      3.040000e+07
# Name: salary, dtype: float64

# %%
df["remote_ratio"].describe()
# Out:
# count    607.00000
# mean      70.92257
# std       40.70913
# min        0.00000
# 25%       50.00000
# 50%      100.00000
# 75%      100.00000
# max      100.00000
# Name: remote_ratio, dtype: float64

# %%
df_g=df.groupby('experience_level')['salary'].apply(lambda x:x.mode().iloc[0]).reset_index()
df_g.columns=['experience_level','salary']
df_g
# Out:
#   experience_level  salary
# 0               EN  100000
# 1               EX  110000
# 2               MI   75000
# 3               SE   80000

# %%
df["remote_ratio"].reset_index()
# Out:
#      index  remote_ratio
# 0        0             0
# 1        1             0
# 2        2            50
# 3        3             0
# 4        4            50
# ..     ...           ...
# 602    602           100
# 603    603           100
# 604    604             0
# 605    605           100
# 606    606           100
#
# [607 rows x 2 columns]

# %%
df.remote_ratio.value_counts().plot(kind='bar',figsize=(10,4))
# Out:
# <Axes: xlabel='remote_ratio'>

# %%
df["remote_ratio"].describe()
# Out:
# count    607.00000
# mean      70.92257
# std       40.70913
# min        0.00000
# 25%       50.00000
# 50%      100.00000
# 75%      100.00000
# max      100.00000
# Name: remote_ratio, dtype: float64
